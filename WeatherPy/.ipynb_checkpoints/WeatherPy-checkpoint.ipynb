# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
count = len(cities)
count
# Out:
# 645

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_data = []
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print('Beginning Data Retrieval     ')
print('-----------------------------')
n = 1
for city_name in cities: #city_names:
    print(f'Processing Record {n} of {count} | {city_name}')
    n = n+1
    try:
        response = requests.get(query_url + city_name).json()
        lattitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        temperature = response["main"]["temp_max"]
        humidity = response["main"]["humidity"]
        cloudiness = response["clouds"]["all"]
        wind_speed = response["wind"]["speed"]
        country = response["sys"]["country"]
        date = response["dt"]
        weather_results = []
        items = [city_name, lattitude, longitude, temperature, humidity, cloudiness, wind_speed, country, date]
        for item in items:
            weather_results.append(item)
        weather_data.append(weather_results)
    except Exception:
        print(f'{city_name} not found. Skipping...')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of 645 | pathein
# Processing Record 2 of 645 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 3 of 645 | ushuaia
# Processing Record 4 of 645 | cabo san lucas
# Processing Record 5 of 645 | kapaa
# Processing Record 6 of 645 | mataura
# Processing Record 7 of 645 | halalo
# halalo not found. Skipping...
# Processing Record 8 of 645 | port augusta
# Processing Record 9 of 645 | nanortalik
# Processing Record 10 of 645 | karratha
# Processing Record 11 of 645 | puerto ayora
# Processing Record 12 of 645 | east london
# Processing Record 13 of 645 | ponta do sol
# Processing Record 14 of 645 | avarua
# Processing Record 15 of 645 | dikson
# Processing Record 16 of 645 | novyy urengoy
# Processing Record 17 of 645 | hobart
# Processing Record 18 of 645 | faanui
# Processing Record 19 of 645 | mattru
# Processing Record 20 of 645 | tanda
# Processing Record 21 of 645 | chokurdakh
# Processing Record 22 of 645 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 23 of 645 | grand gaube
# Processing Record 24 of 645 | yellowknife
# Processing Record 25 of 645 | marcona
# marcona not found. Skipping...
# Processing Record 26 of 645 | malangali
# Processing Record 27 of 645 | kahului
# Processing Record 28 of 645 | busselton
# Processing Record 29 of 645 | kavaratti
# Processing Record 30 of 645 | amderma
# amderma not found. Skipping...
# Processing Record 31 of 645 | punta arenas
# Processing Record 32 of 645 | sibolga
# Processing Record 33 of 645 | coihaique
# Processing Record 34 of 645 | radhanpur
# Processing Record 35 of 645 | yulara
# Processing Record 36 of 645 | chuy
# Processing Record 37 of 645 | torbay
# Processing Record 38 of 645 | ketchikan
# Processing Record 39 of 645 | novosheshminsk
# Processing Record 40 of 645 | cherskiy
# Processing Record 41 of 645 | pervomayskiy
# Processing Record 42 of 645 | vaini
# Processing Record 43 of 645 | new norfolk
# Processing Record 44 of 645 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 45 of 645 | praia
# Processing Record 46 of 645 | butaritari
# Processing Record 47 of 645 | invermere
# Processing Record 48 of 645 | myskhako
# Processing Record 49 of 645 | jos
# Processing Record 50 of 645 | souillac
# Processing Record 51 of 645 | turukhansk
# Processing Record 52 of 645 | port alfred
# Processing Record 53 of 645 | longyearbyen
# Processing Record 54 of 645 | severo-kurilsk
# Processing Record 55 of 645 | den helder
# Processing Record 56 of 645 | ruteng
# Processing Record 57 of 645 | fairbanks
# Processing Record 58 of 645 | barrow
# Processing Record 59 of 645 | aksu
# Processing Record 60 of 645 | alyangula
# Processing Record 61 of 645 | hermanus
# Processing Record 62 of 645 | ust-nera
# Processing Record 63 of 645 | tuscaloosa
# Processing Record 64 of 645 | castro
# Processing Record 65 of 645 | ambovombe
# Processing Record 66 of 645 | auki
# Processing Record 67 of 645 | fortuna
# Processing Record 68 of 645 | kaitangata
# Processing Record 69 of 645 | tyulyachi
# Processing Record 70 of 645 | saint george
# Processing Record 71 of 645 | sao filipe
# Processing Record 72 of 645 | jian
# Processing Record 73 of 645 | yanam
# Processing Record 74 of 645 | amapa
# Processing Record 75 of 645 | marsh harbour
# Processing Record 76 of 645 | esperance
# Processing Record 77 of 645 | los llanos de aridane
# Processing Record 78 of 645 | atar
# Processing Record 79 of 645 | estelle
# Processing Record 80 of 645 | walvis bay
# Processing Record 81 of 645 | bologoye
# Processing Record 82 of 645 | mlimba
# Processing Record 83 of 645 | nikolskoye
# Processing Record 84 of 645 | yamethin
# Processing Record 85 of 645 | rikitea
# Processing Record 86 of 645 | alboraya
# Processing Record 87 of 645 | bukama
# Processing Record 88 of 645 | bredasdorp
# Processing Record 89 of 645 | emba
# Processing Record 90 of 645 | sorland
# Processing Record 91 of 645 | kedgwick
# Processing Record 92 of 645 | wanxian
# Processing Record 93 of 645 | orocue
# Processing Record 94 of 645 | hamilton
# Processing Record 95 of 645 | necochea
# Processing Record 96 of 645 | doctor pedro p. pena
# doctor pedro p. pena not found. Skipping...
# Processing Record 97 of 645 | iquique
# Processing Record 98 of 645 | carnarvon
# Processing Record 99 of 645 | atuona
# Processing Record 100 of 645 | grafton
# Processing Record 101 of 645 | mar del plata
# Processing Record 102 of 645 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing Record 103 of 645 | laguna
# Processing Record 104 of 645 | aasiaat
# Processing Record 105 of 645 | prachuap khiri khan
# Processing Record 106 of 645 | upernavik
# Processing Record 107 of 645 | beloha
# Processing Record 108 of 645 | ler
# Processing Record 109 of 645 | muros
# Processing Record 110 of 645 | tuatapere
# Processing Record 111 of 645 | geraldton
# Processing Record 112 of 645 | kolpashevo
# Processing Record 113 of 645 | qaanaaq
# Processing Record 114 of 645 | terra boa
# Processing Record 115 of 645 | deniliquin
# Processing Record 116 of 645 | neiafu
# Processing Record 117 of 645 | pevek
# Processing Record 118 of 645 | coruripe
# Processing Record 119 of 645 | babu
# Processing Record 120 of 645 | kloulklubed
# Processing Record 121 of 645 | hilo
# Processing Record 122 of 645 | kodiak
# Processing Record 123 of 645 | clyde river
# Processing Record 124 of 645 | elliot
# Processing Record 125 of 645 | nabire
# Processing Record 126 of 645 | bluff
# Processing Record 127 of 645 | male
# Processing Record 128 of 645 | tabou
# Processing Record 129 of 645 | yatou
# Processing Record 130 of 645 | buarcos
# Processing Record 131 of 645 | victoria
# Processing Record 132 of 645 | ahipara
# Processing Record 133 of 645 | rocha
# Processing Record 134 of 645 | terrace
# Processing Record 135 of 645 | williams lake
# Processing Record 136 of 645 | marsabit
# Processing Record 137 of 645 | bambous virieux
# Processing Record 138 of 645 | albany
# Processing Record 139 of 645 | karauzyak
# karauzyak not found. Skipping...
# Processing Record 140 of 645 | tuktoyaktuk
# Processing Record 141 of 645 | raudeberg
# Processing Record 142 of 645 | saint-philippe
# Processing Record 143 of 645 | maxixe
# Processing Record 144 of 645 | jamestown
# Processing Record 145 of 645 | bilibino
# Processing Record 146 of 645 | capinopolis
# Processing Record 147 of 645 | komsomolskiy
# Processing Record 148 of 645 | kavieng
# Processing Record 149 of 645 | cabedelo
# Processing Record 150 of 645 | zhigansk
# Processing Record 151 of 645 | chapais
# Processing Record 152 of 645 | springdale
# Processing Record 153 of 645 | ribeira grande
# Processing Record 154 of 645 | oranjemund
# Processing Record 155 of 645 | calabar
# Processing Record 156 of 645 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 157 of 645 | camopi
# Processing Record 158 of 645 | cockburn town
# Processing Record 159 of 645 | verkhoyansk
# Processing Record 160 of 645 | inzer
# Processing Record 161 of 645 | tamazulapam
# tamazulapam not found. Skipping...
# Processing Record 162 of 645 | sakakah
# Processing Record 163 of 645 | vila velha
# Processing Record 164 of 645 | torit
# Processing Record 165 of 645 | poum
# Processing Record 166 of 645 | rio grande
# Processing Record 167 of 645 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 168 of 645 | iberia
# Processing Record 169 of 645 | korla
# Processing Record 170 of 645 | alta floresta
# Processing Record 171 of 645 | elk city
# Processing Record 172 of 645 | dalvik
# Processing Record 173 of 645 | airai
# Processing Record 174 of 645 | belaya kholunitsa
# Processing Record 175 of 645 | dunedin
# Processing Record 176 of 645 | sinnamary
# Processing Record 177 of 645 | eureka
# Processing Record 178 of 645 | chifeng
# Processing Record 179 of 645 | mahebourg
# Processing Record 180 of 645 | tasiilaq
# Processing Record 181 of 645 | arraial do cabo
# Processing Record 182 of 645 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 183 of 645 | preobrazheniye
# Processing Record 184 of 645 | khatanga
# Processing Record 185 of 645 | aflu
# aflu not found. Skipping...
# Processing Record 186 of 645 | sarangani
# Processing Record 187 of 645 | beringovskiy
# Processing Record 188 of 645 | porto novo
# Processing Record 189 of 645 | tshela
# Processing Record 190 of 645 | esfarayen
# Processing Record 191 of 645 | brae
# Processing Record 192 of 645 | valdivia
# Processing Record 193 of 645 | sao gabriel da cachoeira
# Processing Record 194 of 645 | lavrentiya
# Processing Record 195 of 645 | methoni
# Processing Record 196 of 645 | mokhsogollokh
# Processing Record 197 of 645 | mazyr
# Processing Record 198 of 645 | bolshiye uki
# bolshiye uki not found. Skipping...
# Processing Record 199 of 645 | cape town
# Processing Record 200 of 645 | puerto ayacucho
# Processing Record 201 of 645 | rio gallegos
# Processing Record 202 of 645 | arman
# Processing Record 203 of 645 | fairlie
# Processing Record 204 of 645 | lagoa
# Processing Record 205 of 645 | hithadhoo
# Processing Record 206 of 645 | oum hadjer
# Processing Record 207 of 645 | ngunguru
# Processing Record 208 of 645 | ruatoria
# ruatoria not found. Skipping...
# Processing Record 209 of 645 | bandarbeyla
# Processing Record 210 of 645 | vestmanna
# Processing Record 211 of 645 | sandwick
# Processing Record 212 of 645 | margate
# Processing Record 213 of 645 | zaozhuang
# Processing Record 214 of 645 | egvekinot
# Processing Record 215 of 645 | tura
# Processing Record 216 of 645 | dandong
# Processing Record 217 of 645 | zlobin
# Processing Record 218 of 645 | le port
# Processing Record 219 of 645 | ilulissat
# Processing Record 220 of 645 | tateyama
# Processing Record 221 of 645 | arroyo
# Processing Record 222 of 645 | skjervoy
# Processing Record 223 of 645 | miles city
# Processing Record 224 of 645 | paamiut
# Processing Record 225 of 645 | saint anthony
# Processing Record 226 of 645 | yumen
# Processing Record 227 of 645 | plettenberg bay
# Processing Record 228 of 645 | port blair
# Processing Record 229 of 645 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 230 of 645 | acapulco
# Processing Record 231 of 645 | berlevag
# Processing Record 232 of 645 | vnanje gorice
# Processing Record 233 of 645 | palauig
# Processing Record 234 of 645 | amalapuram
# Processing Record 235 of 645 | isangel
# Processing Record 236 of 645 | belaya gora
# Processing Record 237 of 645 | namibe
# Processing Record 238 of 645 | provideniya
# Processing Record 239 of 645 | batagay-alyta
# Processing Record 240 of 645 | lompoc
# Processing Record 241 of 645 | china
# Processing Record 242 of 645 | niono
# Processing Record 243 of 645 | urumqi
# Processing Record 244 of 645 | deh rawud
# deh rawud not found. Skipping...
# Processing Record 245 of 645 | puri
# Processing Record 246 of 645 | ostrovnoy
# Processing Record 247 of 645 | peniche
# Processing Record 248 of 645 | denpasar
# Processing Record 249 of 645 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 250 of 645 | dingle
# Processing Record 251 of 645 | marienburg
# Processing Record 252 of 645 | lexington
# Processing Record 253 of 645 | bethel
# Processing Record 254 of 645 | yerbogachen
# Processing Record 255 of 645 | hasaki
# Processing Record 256 of 645 | finote selam
# Processing Record 257 of 645 | port keats
# Processing Record 258 of 645 | pemangkat
# Processing Record 259 of 645 | susanino
# Processing Record 260 of 645 | touros
# Processing Record 261 of 645 | iqaluit
# Processing Record 262 of 645 | norman wells
# Processing Record 263 of 645 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 264 of 645 | georgetown
# Processing Record 265 of 645 | muli
# Processing Record 266 of 645 | strezhevoy
# Processing Record 267 of 645 | toba
# Processing Record 268 of 645 | yaan
# Processing Record 269 of 645 | hefei
# Processing Record 270 of 645 | bonavista
# Processing Record 271 of 645 | george
# Processing Record 272 of 645 | saint-joseph
# Processing Record 273 of 645 | aswan
# Processing Record 274 of 645 | turka
# Processing Record 275 of 645 | comodoro rivadavia
# Processing Record 276 of 645 | valparaiso
# Processing Record 277 of 645 | jiazi
# Processing Record 278 of 645 | bay roberts
# Processing Record 279 of 645 | lethem
# Processing Record 280 of 645 | ruhengeri
# Processing Record 281 of 645 | salamanca
# Processing Record 282 of 645 | cidreira
# Processing Record 283 of 645 | narsaq
# Processing Record 284 of 645 | kencong
# Processing Record 285 of 645 | kroya
# Processing Record 286 of 645 | duluth
# Processing Record 287 of 645 | mariental
# Processing Record 288 of 645 | ojinaga
# Processing Record 289 of 645 | sola
# Processing Record 290 of 645 | shelburne
# Processing Record 291 of 645 | tanout
# Processing Record 292 of 645 | cabo rojo
# Processing Record 293 of 645 | jabiru
# jabiru not found. Skipping...
# Processing Record 294 of 645 | nome
# Processing Record 295 of 645 | puerto leguizamo
# Processing Record 296 of 645 | sakiai
# Processing Record 297 of 645 | kruisfontein
# Processing Record 298 of 645 | namatanai
# Processing Record 299 of 645 | coquimbo
# Processing Record 300 of 645 | camana
# Processing Record 301 of 645 | vaitape
# Processing Record 302 of 645 | podgornoye
# Processing Record 303 of 645 | wardenburg
# Processing Record 304 of 645 | fort portal
# Processing Record 305 of 645 | progreso
# Processing Record 306 of 645 | sobolevo
# Processing Record 307 of 645 | luderitz
# Processing Record 308 of 645 | groningen
# Processing Record 309 of 645 | west bay
# Processing Record 310 of 645 | zaysan
# Processing Record 311 of 645 | senmonorom
# senmonorom not found. Skipping...
# Processing Record 312 of 645 | port elizabeth
# Processing Record 313 of 645 | mahibadhoo
# Processing Record 314 of 645 | san quintin
# Processing Record 315 of 645 | kolosovka
# Processing Record 316 of 645 | yar-sale
# Processing Record 317 of 645 | shimoda
# Processing Record 318 of 645 | praya
# Processing Record 319 of 645 | praia da vitoria
# Processing Record 320 of 645 | saldanha
# Processing Record 321 of 645 | saskylakh
# Processing Record 322 of 645 | lebu
# Processing Record 323 of 645 | porosozero
# Processing Record 324 of 645 | lata
# Processing Record 325 of 645 | muzhi
# Processing Record 326 of 645 | buqayq
# buqayq not found. Skipping...
# Processing Record 327 of 645 | viedma
# Processing Record 328 of 645 | cortez
# Processing Record 329 of 645 | khash
# Processing Record 330 of 645 | eldorado
# Processing Record 331 of 645 | amuntai
# Processing Record 332 of 645 | malpura
# Processing Record 333 of 645 | baruun-urt
# Processing Record 334 of 645 | mumbwa
# Processing Record 335 of 645 | kamenskoye
# kamenskoye not found. Skipping...
# Processing Record 336 of 645 | sorong
# Processing Record 337 of 645 | samarai
# Processing Record 338 of 645 | hobyo
# Processing Record 339 of 645 | rivarolo canavese
# Processing Record 340 of 645 | kabo
# Processing Record 341 of 645 | milkovo
# Processing Record 342 of 645 | mabamba
# Processing Record 343 of 645 | nhulunbuy
# Processing Record 344 of 645 | gold coast
# Processing Record 345 of 645 | labutta
# labutta not found. Skipping...
# Processing Record 346 of 645 | varzea da palma
# Processing Record 347 of 645 | thompson
# Processing Record 348 of 645 | isla mujeres
# Processing Record 349 of 645 | lerwick
# Processing Record 350 of 645 | anadyr
# Processing Record 351 of 645 | bengkulu
# Processing Record 352 of 645 | padang
# Processing Record 353 of 645 | yenagoa
# Processing Record 354 of 645 | makakilo city
# Processing Record 355 of 645 | ijaki
# ijaki not found. Skipping...
# Processing Record 356 of 645 | bilma
# Processing Record 357 of 645 | seymchan
# Processing Record 358 of 645 | thessalon
# Processing Record 359 of 645 | great falls
# Processing Record 360 of 645 | guaruja
# Processing Record 361 of 645 | launceston
# Processing Record 362 of 645 | huarmey
# Processing Record 363 of 645 | ekhabi
# Processing Record 364 of 645 | huilong
# Processing Record 365 of 645 | college
# Processing Record 366 of 645 | bunol
# Processing Record 367 of 645 | moron
# Processing Record 368 of 645 | parral
# Processing Record 369 of 645 | mecca
# Processing Record 370 of 645 | asau
# Processing Record 371 of 645 | mayo
# Processing Record 372 of 645 | payo
# Processing Record 373 of 645 | penzance
# Processing Record 374 of 645 | zyryanka
# Processing Record 375 of 645 | guerrero negro
# Processing Record 376 of 645 | karlstad
# Processing Record 377 of 645 | vallenar
# Processing Record 378 of 645 | coahuayana
# Processing Record 379 of 645 | tilichiki
# Processing Record 380 of 645 | rantepao
# Processing Record 381 of 645 | hami
# Processing Record 382 of 645 | sri madhopur
# Processing Record 383 of 645 | kazerun
# Processing Record 384 of 645 | tabiauea
# tabiauea not found. Skipping...
# Processing Record 385 of 645 | datong
# Processing Record 386 of 645 | muriwai beach
# Processing Record 387 of 645 | cachoeira do sul
# Processing Record 388 of 645 | sinkat
# sinkat not found. Skipping...
# Processing Record 389 of 645 | wulanhaote
# wulanhaote not found. Skipping...
# Processing Record 390 of 645 | flinders
# Processing Record 391 of 645 | tabuk
# Processing Record 392 of 645 | inta
# Processing Record 393 of 645 | yarmouth
# Processing Record 394 of 645 | ganzhou
# Processing Record 395 of 645 | yarkovo
# Processing Record 396 of 645 | labuan
# Processing Record 397 of 645 | channel-port aux basques
# Processing Record 398 of 645 | camacha
# Processing Record 399 of 645 | reefton
# reefton not found. Skipping...
# Processing Record 400 of 645 | san policarpo
# Processing Record 401 of 645 | tocopilla
# Processing Record 402 of 645 | teahupoo
# Processing Record 403 of 645 | high level
# Processing Record 404 of 645 | fort saint james
# Processing Record 405 of 645 | saleaula
# saleaula not found. Skipping...
# Processing Record 406 of 645 | mareeba
# Processing Record 407 of 645 | lolua
# lolua not found. Skipping...
# Processing Record 408 of 645 | verkh-usugli
# Processing Record 409 of 645 | manokwari
# Processing Record 410 of 645 | san patricio
# Processing Record 411 of 645 | umm durman
# umm durman not found. Skipping...
# Processing Record 412 of 645 | davila
# Processing Record 413 of 645 | la ronge
# Processing Record 414 of 645 | borogontsy
# Processing Record 415 of 645 | bodden town
# Processing Record 416 of 645 | tornio
# Processing Record 417 of 645 | bubaque
# Processing Record 418 of 645 | adrar
# Processing Record 419 of 645 | lazaro cardenas
# Processing Record 420 of 645 | gravelbourg
# Processing Record 421 of 645 | kaberamaido
# Processing Record 422 of 645 | mocuba
# Processing Record 423 of 645 | adilabad
# Processing Record 424 of 645 | wawa
# Processing Record 425 of 645 | sergeyevka
# Processing Record 426 of 645 | fukue
# Processing Record 427 of 645 | kidal
# Processing Record 428 of 645 | sukhaya buyvola
# Processing Record 429 of 645 | mehamn
# Processing Record 430 of 645 | shache
# Processing Record 431 of 645 | cayenne
# Processing Record 432 of 645 | urkarakh
# Processing Record 433 of 645 | bonthe
# Processing Record 434 of 645 | kerteh
# kerteh not found. Skipping...
# Processing Record 435 of 645 | mayna
# Processing Record 436 of 645 | port-gentil
# Processing Record 437 of 645 | katsuura
# Processing Record 438 of 645 | kharp
# Processing Record 439 of 645 | te anau
# Processing Record 440 of 645 | salalah
# Processing Record 441 of 645 | waingapu
# Processing Record 442 of 645 | khandyga
# Processing Record 443 of 645 | gillette
# Processing Record 444 of 645 | rudnogorsk
# Processing Record 445 of 645 | sept-iles
# Processing Record 446 of 645 | kinsale
# Processing Record 447 of 645 | zhangjiakou
# Processing Record 448 of 645 | patti
# Processing Record 449 of 645 | svetlyy
# Processing Record 450 of 645 | mrakovo
# Processing Record 451 of 645 | lorengau
# Processing Record 452 of 645 | port lincoln
# Processing Record 453 of 645 | half moon bay
# Processing Record 454 of 645 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 455 of 645 | khunti
# Processing Record 456 of 645 | kaniama
# Processing Record 457 of 645 | norsup
# Processing Record 458 of 645 | sambava
# Processing Record 459 of 645 | moussoro
# Processing Record 460 of 645 | ialibu
# Processing Record 461 of 645 | chicama
# Processing Record 462 of 645 | verkhnevilyuysk
# Processing Record 463 of 645 | hofn
# Processing Record 464 of 645 | malko tarnovo
# Processing Record 465 of 645 | vazhiny
# Processing Record 466 of 645 | opportunity
# Processing Record 467 of 645 | gao
# Processing Record 468 of 645 | ustye
# Processing Record 469 of 645 | poya
# Processing Record 470 of 645 | cagayan de tawi-tawi
# cagayan de tawi-tawi not found. Skipping...
# Processing Record 471 of 645 | solnechnyy
# Processing Record 472 of 645 | opuwo
# Processing Record 473 of 645 | petropavlovsk-kamchatskiy
# Processing Record 474 of 645 | hambantota
# Processing Record 475 of 645 | ponta delgada
# Processing Record 476 of 645 | fare
# Processing Record 477 of 645 | doha
# Processing Record 478 of 645 | meulaboh
# Processing Record 479 of 645 | odweyne
# Processing Record 480 of 645 | athabasca
# Processing Record 481 of 645 | sao joao da barra
# Processing Record 482 of 645 | crotone
# Processing Record 483 of 645 | busayra
# Processing Record 484 of 645 | constitucion
# Processing Record 485 of 645 | victor harbor
# Processing Record 486 of 645 | revda
# Processing Record 487 of 645 | byron bay
# Processing Record 488 of 645 | saint-augustin
# Processing Record 489 of 645 | blyth
# Processing Record 490 of 645 | sitka
# Processing Record 491 of 645 | roebourne
# Processing Record 492 of 645 | nokaneng
# Processing Record 493 of 645 | salvador
# Processing Record 494 of 645 | baykit
# Processing Record 495 of 645 | vila franca do campo
# Processing Record 496 of 645 | leningradskiy
# Processing Record 497 of 645 | lhuntshi
# lhuntshi not found. Skipping...
# Processing Record 498 of 645 | culipapa
# culipapa not found. Skipping...
# Processing Record 499 of 645 | zabol
# Processing Record 500 of 645 | severobaykalsk
# Processing Record 501 of 645 | biak
# Processing Record 502 of 645 | ancud
# Processing Record 503 of 645 | vardo
# Processing Record 504 of 645 | port hedland
# Processing Record 505 of 645 | soke
# Processing Record 506 of 645 | tommot
# Processing Record 507 of 645 | neepawa
# Processing Record 508 of 645 | ormara
# Processing Record 509 of 645 | umm kaddadah
# Processing Record 510 of 645 | thano bula khan
# thano bula khan not found. Skipping...
# Processing Record 511 of 645 | itacarambi
# Processing Record 512 of 645 | tezu
# Processing Record 513 of 645 | gloucester
# Processing Record 514 of 645 | qandala
# Processing Record 515 of 645 | mokhotlong
# Processing Record 516 of 645 | kutum
# Processing Record 517 of 645 | jumla
# Processing Record 518 of 645 | dibaya
# dibaya not found. Skipping...
# Processing Record 519 of 645 | bud
# Processing Record 520 of 645 | tamandare
# Processing Record 521 of 645 | udachnyy
# Processing Record 522 of 645 | lufilufi
# Processing Record 523 of 645 | kudahuvadhoo
# Processing Record 524 of 645 | noumea
# Processing Record 525 of 645 | aripuana
# Processing Record 526 of 645 | vrangel
# Processing Record 527 of 645 | marawi
# Processing Record 528 of 645 | maniitsoq
# Processing Record 529 of 645 | umzimvubu
# umzimvubu not found. Skipping...
# Processing Record 530 of 645 | dakar
# Processing Record 531 of 645 | qasigiannguit
# Processing Record 532 of 645 | puerto escondido
# Processing Record 533 of 645 | yei
# Processing Record 534 of 645 | ust-ilimsk
# Processing Record 535 of 645 | ambilobe
# Processing Record 536 of 645 | urucara
# Processing Record 537 of 645 | calamar
# Processing Record 538 of 645 | brookings
# Processing Record 539 of 645 | san andres
# Processing Record 540 of 645 | hanna
# Processing Record 541 of 645 | gizo
# Processing Record 542 of 645 | cabra
# Processing Record 543 of 645 | ligayan
# Processing Record 544 of 645 | sulangan
# Processing Record 545 of 645 | ucluelet
# Processing Record 546 of 645 | nyalikungu
# Processing Record 547 of 645 | aranos
# Processing Record 548 of 645 | gravdal
# Processing Record 549 of 645 | santa maria da boa vista
# Processing Record 550 of 645 | tiznit
# Processing Record 551 of 645 | oga
# Processing Record 552 of 645 | sao felix do xingu
# Processing Record 553 of 645 | kushmurun
# Processing Record 554 of 645 | mount gambier
# Processing Record 555 of 645 | hihifo
# hihifo not found. Skipping...
# Processing Record 556 of 645 | perelyub
# Processing Record 557 of 645 | dicabisagan
# Processing Record 558 of 645 | husavik
# Processing Record 559 of 645 | tual
# Processing Record 560 of 645 | creston
# Processing Record 561 of 645 | moses lake
# Processing Record 562 of 645 | senanga
# Processing Record 563 of 645 | alice springs
# Processing Record 564 of 645 | taksimo
# Processing Record 565 of 645 | kholtoson
# Processing Record 566 of 645 | vilyuysk
# Processing Record 567 of 645 | santiago del estero
# Processing Record 568 of 645 | karaul
# karaul not found. Skipping...
# Processing Record 569 of 645 | tiksi
# Processing Record 570 of 645 | klaksvik
# Processing Record 571 of 645 | nelson bay
# Processing Record 572 of 645 | armacao dos buzios
# armacao dos buzios not found. Skipping...
# Processing Record 573 of 645 | barbar
# barbar not found. Skipping...
# Processing Record 574 of 645 | misratah
# Processing Record 575 of 645 | henderson
# Processing Record 576 of 645 | macapa
# Processing Record 577 of 645 | anyang
# Processing Record 578 of 645 | zorgo
# Processing Record 579 of 645 | kupang
# Processing Record 580 of 645 | artyk
# artyk not found. Skipping...
# Processing Record 581 of 645 | tahe
# Processing Record 582 of 645 | port hardy
# Processing Record 583 of 645 | ust-bolsheretsk
# ust-bolsheretsk not found. Skipping...
# Processing Record 584 of 645 | oyama
# Processing Record 585 of 645 | arlit
# Processing Record 586 of 645 | tubruq
# tubruq not found. Skipping...
# Processing Record 587 of 645 | gulshat
# gulshat not found. Skipping...
# Processing Record 588 of 645 | ostersund
# Processing Record 589 of 645 | yanan
# yanan not found. Skipping...
# Processing Record 590 of 645 | bambanglipuro
# Processing Record 591 of 645 | la asuncion
# Processing Record 592 of 645 | kirakira
# Processing Record 593 of 645 | pringsewu
# Processing Record 594 of 645 | atambua
# Processing Record 595 of 645 | mandali
# Processing Record 596 of 645 | merauke
# Processing Record 597 of 645 | vokhtoga
# Processing Record 598 of 645 | raga
# Processing Record 599 of 645 | hay river
# Processing Record 600 of 645 | kajaani
# Processing Record 601 of 645 | pangai
# Processing Record 602 of 645 | teguldet
# Processing Record 603 of 645 | miandrivazo
# Processing Record 604 of 645 | nurota
# Processing Record 605 of 645 | kolyubakino
# Processing Record 606 of 645 | domoni
# Processing Record 607 of 645 | morros
# Processing Record 608 of 645 | hammerfest
# Processing Record 609 of 645 | boralday
# Processing Record 610 of 645 | mount isa
# Processing Record 611 of 645 | whitehorse
# Processing Record 612 of 645 | san felipe
# Processing Record 613 of 645 | broome
# Processing Record 614 of 645 | seoul
# Processing Record 615 of 645 | ebolowa
# Processing Record 616 of 645 | beberibe
# Processing Record 617 of 645 | louisbourg
# louisbourg not found. Skipping...
# Processing Record 618 of 645 | ouallam
# Processing Record 619 of 645 | itoman
# Processing Record 620 of 645 | diu
# Processing Record 621 of 645 | salina cruz
# Processing Record 622 of 645 | navirai
# Processing Record 623 of 645 | yarega
# Processing Record 624 of 645 | altay
# Processing Record 625 of 645 | wainwright
# Processing Record 626 of 645 | bokhan
# Processing Record 627 of 645 | toila
# Processing Record 628 of 645 | moose factory
# Processing Record 629 of 645 | aklavik
# Processing Record 630 of 645 | tucumcari
# Processing Record 631 of 645 | repalle
# Processing Record 632 of 645 | barabai
# Processing Record 633 of 645 | chudovo
# Processing Record 634 of 645 | purranque
# Processing Record 635 of 645 | viligili
# viligili not found. Skipping...
# Processing Record 636 of 645 | bara
# Processing Record 637 of 645 | gloversville
# Processing Record 638 of 645 | gouyave
# Processing Record 639 of 645 | ayan
# Processing Record 640 of 645 | cairns
# Processing Record 641 of 645 | shubarkuduk
# Processing Record 642 of 645 | port-de-paix
# port-de-paix not found. Skipping...
# Processing Record 643 of 645 | barcelona
# Processing Record 644 of 645 | sahrak
# sahrak not found. Skipping...
# Processing Record 645 of 645 | otane

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data = pd.DataFrame(weather_data,columns=['City','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Country','Date'])
city_data.to_csv(output_data_file)
city_data
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           pathein  16.78   94.73     81.14        87         100
# 1           ushuaia -54.80  -68.30     41.00        94          20
# 2    cabo san lucas  22.89 -109.91     82.99        79           0
# 3             kapaa  22.08 -159.32     80.60        78          40
# 4           mataura -46.19  168.86     57.00        59          76
# ..              ...    ...     ...       ...       ...         ...
# 586            ayan  56.45  138.17     39.33        67          68
# 587          cairns -16.92  145.77     86.00        48           3
# 588     shubarkuduk  49.14   56.49     53.26        41          76
# 589       barcelona  41.39    2.16     52.00        70          20
# 590           otane -39.88  176.63     57.99        66          89
#
#      Wind Speed Country        Date
# 0          9.24      MM  1602907431
# 1         19.46      AR  1602907431
# 2          4.43      MX  1602907317
# 3          8.05      US  1602907432
# 4          1.99      NZ  1602907255
# ..          ...     ...         ...
# 586        2.66      RU  1602907504
# 587       13.87      AU  1602907270
# 588       11.23      KZ  1602907504
# 589       12.75      ES  1602907207
# 590        1.99      NZ  1602907505
#
# [591 rows x 9 columns]

# %%
city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  591.000000  591.000000  591.000000  591.000000  591.000000  591.000000
# mean    20.648883   21.222047   59.852809   72.248731   53.913706    8.048409
# std     33.778080   91.261581   19.949167   20.982496   39.158015    5.765045
# min    -54.800000 -179.170000    1.710000   10.000000    0.000000    0.290000
# 25%     -8.375000  -55.210000   44.010000   60.500000   11.500000    3.830000
# 50%     23.080000   25.680000   62.600000   77.000000   64.000000    6.930000
# 75%     50.975000  103.760000   77.380000   88.000000   90.000000   10.290000
# max     78.220000  179.320000   98.600000  100.000000  100.000000   42.460000
#
#                Date
# count  5.910000e+02
# mean   1.602907e+09
# std    6.896194e+01
# min    1.602907e+09
# 25%    1.602907e+09
# 50%    1.602907e+09
# 75%    1.602907e+09
# max    1.602908e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
c_d = city_data[city_data['Humidity'] > 100]
print(f'There are {len(c_d)} cities that have humidity over 100%')
city_data = city_data[city_data['Humidity'] <= 100]
city_data.describe()
# Out:
# There are 0 cities that have humidity over 100%
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  591.000000  591.000000  591.000000  591.000000  591.000000  591.000000
# mean    20.648883   21.222047   59.852809   72.248731   53.913706    8.048409
# std     33.778080   91.261581   19.949167   20.982496   39.158015    5.765045
# min    -54.800000 -179.170000    1.710000   10.000000    0.000000    0.290000
# 25%     -8.375000  -55.210000   44.010000   60.500000   11.500000    3.830000
# 50%     23.080000   25.680000   62.600000   77.000000   64.000000    6.930000
# 75%     50.975000  103.760000   77.380000   88.000000   90.000000   10.290000
# max     78.220000  179.320000   98.600000  100.000000  100.000000   42.460000
#
#                Date
# count  5.910000e+02
# mean   1.602907e+09
# std    6.896194e+01
# min    1.602907e+09
# 25%    1.602907e+09
# 50%    1.602907e+09
# 75%    1.602907e+09
# max    1.602908e+09

# %%
#  Get the indices of cities that have humidity over 100%.
indices = list(c_d.index.values)
print(indices)
print(f'There are {len(indices)} cities that have humidity over 100%')
# Out:
# []
# There are 0 cities that have humidity over 100%

# %%
# Make a new DataFrame called "clean_city_data" equal to the city data to drop all humidity outliers by index.
clean_city_data = city_data[city_data['Humidity'] <= 100]
clean_city_data
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           pathein  16.78   94.73     81.14        87         100
# 1           ushuaia -54.80  -68.30     41.00        94          20
# 2    cabo san lucas  22.89 -109.91     82.99        79           0
# 3             kapaa  22.08 -159.32     80.60        78          40
# 4           mataura -46.19  168.86     57.00        59          76
# ..              ...    ...     ...       ...       ...         ...
# 586            ayan  56.45  138.17     39.33        67          68
# 587          cairns -16.92  145.77     86.00        48           3
# 588     shubarkuduk  49.14   56.49     53.26        41          76
# 589       barcelona  41.39    2.16     52.00        70          20
# 590           otane -39.88  176.63     57.99        66          89
#
#      Wind Speed Country        Date
# 0          9.24      MM  1602907431
# 1         19.46      AR  1602907431
# 2          4.43      MX  1602907317
# 3          8.05      US  1602907432
# 4          1.99      NZ  1602907255
# ..          ...     ...         ...
# 586        2.66      RU  1602907504
# 587       13.87      AU  1602907270
# 588       11.23      KZ  1602907504
# 589       12.75      ES  1602907207
# 590        1.99      NZ  1602907505
#
# [591 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_city_data['Lat'],clean_city_data['Max Temp'], marker='o', edgecolors = 'black')
plt.title('City Latitude vs. Max Temperature (11/16/20)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data['Lat'],clean_city_data['Humidity'], marker='o', edgecolors = 'black')
plt.title('City Latitude vs. Humidity (11/16/20)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data['Lat'],clean_city_data['Cloudiness'], marker='o', edgecolors = 'black')
plt.title('City Latitude vs. Cloudiness (11/16/20)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data['Lat'],clean_city_data['Wind Speed'], marker='o', edgecolors = 'black')
plt.title('City Latitude vs. Wind Speed (11/16/20)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
north_hem = clean_city_data[clean_city_data['Lat'] >= 0]
south_hem = clean_city_data[clean_city_data['Lat'] < 0]

n_city_lat = north_hem['Lat']
s_city_lat = south_hem['Lat']

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
n_temp = north_hem['Max Temp']
nt_slope, nt_int, nt_r, nt_p, nt_std_err = linregress(n_city_lat,n_temp)
nt_fit = nt_slope * n_city_lat + nt_int
form = 'y= {:.2f}x + {:.2f}'.format(nt_slope,nt_int)
print(f'The r-value is: {nt_r}')
plt.scatter(n_city_lat,n_temp)
plt.plot(n_city_lat,nt_fit,c='r',label= form)
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.legend(labelcolor='r',loc='best', fontsize=12, frameon=False)
plt.grid()
plt.show()
# Out:
# The r-value is: -0.8912663867829825

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_temp = south_hem['Max Temp']
st_slope, st_int, st_r, st_p, st_std_err = linregress(s_city_lat,s_temp)
st_fit = st_slope * s_city_lat + st_int
form = 'y= {:.2f}x + {:.2f}'.format(st_slope,st_int)
print(f'The r-value is: {st_r}')
plt.scatter(s_city_lat,s_temp)
plt.plot(s_city_lat,st_fit,c='r',label= form)
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.legend(labelcolor='r',loc='best', fontsize=12, frameon=False)
plt.grid()
plt.show()
# Out:
# The r-value is: 0.693536889566764

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_hum = north_hem['Humidity']
nh_slope, nh_int, nh_r, nh_p, nh_std_err = linregress(n_city_lat,n_hum)
nh_fit = nh_slope * n_city_lat + nh_int
form = 'y= {:.2f}x + {:.2f}'.format(nh_slope,nh_int)
print(f'The r-value is: {nh_r}')
plt.scatter(n_city_lat,n_hum)
plt.plot(n_city_lat,nh_fit,c='r',label= form)
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.legend(labelcolor='r',loc='best', fontsize=12, frameon=False)
plt.grid()
plt.show()
# Out:
# The r-value is: 0.23978494169305015

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_hum = south_hem['Humidity']
sh_slope, sh_int, sh_r, sh_p, sh_std_err = linregress(s_city_lat,s_hum)
sh_fit = sh_slope * s_city_lat + sh_int
form = 'y= {:.2f}x + {:.2f}'.format(sh_slope,sh_int)
print(f'The r-value is: {sh_r}')
plt.scatter(s_city_lat,s_hum)
plt.plot(s_city_lat,sh_fit,c='r',label= form)
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.legend(labelcolor='r',loc='best', fontsize=12, frameon=False)
plt.grid()
plt.show()
# Out:
# The r-value is: -0.01569371080951621

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_cloud = north_hem['Cloudiness']
nc_slope, nc_int, nc_r, nc_p, nc_std_err = linregress(n_city_lat,n_cloud)
nc_fit = nc_slope * n_city_lat + nc_int
form = 'y= {:.2f}x + {:.2f}'.format(nc_slope,nc_int)
print(f'The r-value is: {nc_r}')
plt.scatter(n_city_lat,n_cloud)
plt.plot(n_city_lat,nc_fit,c='r',label= form)
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.legend(labelcolor='r',loc='best', fontsize=12, frameon=False)
plt.grid()
plt.show()
# Out:
# The r-value is: 0.2671008188526051

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_cloud = south_hem['Cloudiness']
sc_slope, sc_int, sc_r, sc_p, sc_std_err = linregress(s_city_lat,s_cloud)
sc_fit = sc_slope * s_city_lat + sc_int
form = 'y= {:.2f}x + {:.2f}'.format(sc_slope,sc_int)
print(f'The r-value is: {sc_r}')
plt.scatter(s_city_lat,s_cloud)
plt.plot(s_city_lat,sc_fit,c='r',label= form)
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.legend(labelcolor='r',loc='best', fontsize=12, frameon=False)
plt.grid()
plt.show()
# Out:
# The r-value is: 0.09435591766730814

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_wind = north_hem['Wind Speed']
nw_slope, nw_int, nw_r, nw_p, nw_std_err = linregress(n_city_lat,n_wind)
nw_fit = nw_slope * n_city_lat + nw_int
form = 'y= {:.2f}x + {:.2f}'.format(nw_slope,nw_int)
print(f'The r-value is: {nw_r}')
plt.scatter(n_city_lat,n_wind)
plt.plot(n_city_lat,nw_fit,c='r',label= form)
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.legend(labelcolor='r',loc='best', fontsize=12, frameon=False)
plt.grid()
plt.show()
# Out:
# The r-value is: 0.23369819344704

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_wind = south_hem['Wind Speed']
sw_slope, sw_int, sw_r, sw_p, sw_std_err = linregress(s_city_lat,s_wind)
sw_fit = sw_slope * s_city_lat + sw_int
form = 'y= {:.2f}x + {:.2f}'.format(sw_slope,sw_int)
print(f'The r-value is: {sw_r}')
plt.scatter(s_city_lat,s_wind)
plt.plot(s_city_lat,sw_fit,c='r',label= form)
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.legend(labelcolor='r',loc='best', fontsize=12, frameon=False)
plt.grid()
plt.show()
# Out:
# The r-value is: -0.13219821768030507
